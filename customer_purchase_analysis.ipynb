# %%
import pandas as pd 
df = pd.read_excel('customer_purchase_data.xlsx')

# %%
df.head(10)
# Out:
#   CustomerID  Age  Gender     Item Purchase Category Purchase Location Size  \
# 0    CUST001   19  Female    Jeans          Clothing          Gurugram    M
# 1    CUST002   56    Male    Shirt          Clothing          Dehradun    M
# 2    CUST003   27    Male    Dress          Clothing         Hyderabad    S
# 3    CUST004   23  Female  Sandals          Footwear        Chandigarh    L
# 4    CUST005   47  Female    Dress          Clothing         Bangalore    L
# 5    CUST006   58    Male    Dress          Clothing         Hyderabad    S
# 6    CUST007   43  Female   Hoodie          Clothing         Bangalore    L
# 7    CUST008   21    Male    Jeans          Clothing         Bangalore    M
# 8    CUST009   35  Female    Shirt          Clothing            Mumbai    L
# 9    CUST010   56    Male    Shirt          Clothing         Bangalore    L
#
#    Color  Season  Review Rate Subscription Status  Shipping Type  \
# 0   Blue  Spring            5                 Yes   Next Day Air
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              50 non-null     str
#  1   Age                     50 non-null     int64
#  2   Gender                  50 non-null     str
#  3   Item                    50 non-null     str
#  4   Purchase Category       50 non-null     str
#  5   Purchase Location       50 non-null     str
#  6   Size                    50 non-null     str
#  7   Color                   50 non-null     str
#  8   Season                  50 non-null     str
#  9   Review Rate             50 non-null     int64
#  10  Subscription Status     50 non-null     str
#  11  Shipping Type           50 non-null     str
#  12  Discount Amount         50 non-null     int64
#  13  Promo Code Used         50 non-null     str
#  14  Previous Purchases      50 non-null     int64
# ...

# %%
df.describe()
# Out:
#              Age  Review Rate  Discount Amount  Previous Purchases
# count  50.000000     50.00000        50.000000           50.000000
# mean   38.480000      2.98000       148.000000           13.120000
# std    13.650506      1.33233       117.785693            7.330785
# min    19.000000      1.00000         0.000000            0.000000
# 25%    26.250000      2.00000        12.500000            7.000000
# 50%    35.500000      3.00000       150.000000           12.500000
# 75%    52.000000      4.00000       250.000000           20.250000
# max    60.000000      5.00000       300.000000           25.000000

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Age                       0
# Gender                    0
# Item                      0
# Purchase Category         0
# Purchase Location         0
# Size                      0
# Color                     0
# Season                    0
# Review Rate               0
# Subscription Status       0
# Shipping Type             0
# Discount Amount           0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %% [markdown]
# ### Create a Column for age_Group.

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace('_','')

# %%
df.columns
# Out:
# Index(['customerid', 'age', 'gender', 'item', 'purchase category',
#        'purchase location', 'size', 'color', 'season', 'review rate',
#        'subscription status', 'shipping type', 'discount amount',
#        'promo code used', 'previous purchases', 'payment method',
#        'frequency of purchases'],
#       dtype='str')

# %%
labels = ['Young Adult' , 'Adult' , 'Middle-aged' , 'Senior'] 
df['age_group'] = pd.qcut(df['age'], q=4, labels = labels)

# %%
df[['age' , 'age_group']].head(10)
# Out:
#    age    age_group
# 0   19  Young Adult
# 1   56       Senior
# 2   27        Adult
# 3   23  Young Adult
# 4   47  Middle-aged
# 5   58       Senior
# 6   43  Middle-aged
# 7   21  Young Adult
# 8   35        Adult
# 9   56       Senior

# %% [markdown]
# ### Purchase column purhase_frequency_days

# %%
frequency_mapping = {
    'Weekly' : 7,
    'Monthly' : 30,
    'Quarterly' : 90,
    'Annually' : 365
}
df['purchase_frequency_days'] = df['frequency of purchases'].map(frequency_mapping)

# %%
df[['purchase_frequency_days','frequency of purchases']].head(20)
# Out:
#     purchase_frequency_days frequency of purchases
# 0                        30                Monthly
# 1                        90              Quarterly
# 2                         7                 Weekly
# 3                       365               Annually
# 4                       365               Annually
# 5                        30                Monthly
# 6                       365               Annually
# 7                         7                 Weekly
# 8                        90              Quarterly
# 9                        30                Monthly
# 10                       30                Monthly
# 11                       30                Monthly
# 12                       30                Monthly
# 13                        7                 Weekly
# 14                       30                Monthly
# 15                        7                 Weekly
# 16                        7                 Weekly
# ...

# %% [markdown]
# ### code for connecting mysql

# %%
import pymysql

db = pymysql.connect(
    host="127.0.0.1",
    user="root",
    password="shraddha17",
    database="customerdata"
)

cur = db.cursor()

# %%
cursor = db.cursor()

cursor.execute("SHOW TABLES")

for table in cursor:
    print(table)
# Out:
# ('customer_purchase_data',)
